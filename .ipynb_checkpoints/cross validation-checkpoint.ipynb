# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("heart.csv.xls")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df['target'].isnull().sum()
# Out:
# 0

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
X = df.drop(['target'], axis=1)
Y = df['target']

# %%
print(X,Y)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
sc = StandardScaler()
sc.fit(X)
X_stand = sc.transform(X)

# %%
print(X_stand)
# Out:
# [[-0.26843658  0.66150409 -0.91575542 ...  0.99543334  1.20922066
#    1.08985168]
#  [-0.15815703  0.66150409 -0.91575542 ... -2.24367514 -0.73197147
#    1.08985168]
#  [ 1.71659547  0.66150409 -0.91575542 ... -2.24367514 -0.73197147
#    1.08985168]
#  ...
#  [-0.81983438  0.66150409 -0.91575542 ... -0.6241209   0.23862459
#   -0.52212231]
#  [-0.4889957  -1.51170646 -0.91575542 ...  0.99543334 -0.73197147
#   -0.52212231]
#  [-0.04787747  0.66150409 -0.91575542 ... -0.6241209   0.23862459
#    1.08985168]]

# %%
models = [LogisticRegression() , KNeighborsClassifier() , RandomForestClassifier() , SVC(kernel='linear')]

# %%
for model in models:
    cross_val = cross_val_score(model , X_stand , Y , cv= 5)
    mean = (sum(cross_val)/len(cross_val))*100
    print(f'cross value score for {model} =',round(mean , 2))
# Out:
# cross value score for LogisticRegression() = 84.59
# cross value score for KNeighborsClassifier() = 83.32
# cross value score for RandomForestClassifier() = 99.41
# cross value score for SVC(kernel='linear') = 83.51
